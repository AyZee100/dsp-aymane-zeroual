# %% [markdown]
# # House Prices - Final Industrialized Notebook

# %% [markdown]
# ## Model building

# %%
from house_prices.train import build_model

model_performance_dict = build_model('../data/train.csv')
print(model_performance_dict)
# Out:
# {'rmsle': 0.19}

# %% [markdown]
# ## Model inference

# %%
from house_prices.inference import make_predictions

predictions = make_predictions('../data/test.csv')
predictions
# Out:
# array([112528.98609809, 157159.79069386, 191541.74712742, ...,
#        152566.51974532, 145450.33058777, 191039.72177858], shape=(1459,))
